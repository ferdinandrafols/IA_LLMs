# %% [markdown]
# <a href="https://colab.research.google.com/github/ferdinandrafols/IA_LLMs/blob/main/aula_3_transformer_decoder_only_and_inference_V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 3 - Transformer *decoder-only*
#
# Nesta aula você irá modificar o Transformer *decoder-only* fornecido a seguir.
# Observe que em um *decoder-only* não existe:
#
# *   cross-attention
# *   encoder separado
#
# e é utilizado com *auto-regressão*.
#
# ## Objetivo
#
#
# ## Exercício
#
# Neste exercício você deve:
#
# 1.   carregar o seu conjunto de documentos
# 2.   treinar e usar (ou carregar) um tokenizador
# 3.   fazer treino de um modelo decoder-only
# 4.   incluir no loop de treino, inferência usando máxima probabilidade
# 5.   incluir no loop de treino, inferência usando amostragem com temperatura

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %% [markdown]
# # Passo 1: carregar conjunto de documentos

# %%
from datasets import load_dataset
import re

###### INSIRA AQUI O CODIGO PARA CARREGAR OS SEUS DOCUMENTOS na lista DOCUMENTOS
#ds = load_dataset("jquigl/imdb-genres") # Exemplo

def clean_ascii(text):
    text = text.encode("ascii", errors="ignore").decode()
    return re.sub(r"[^A-Za-z0-9 .,:;!?'\-]", "", text)

# Load documents from the provided file
with open("/content/500 Frases Mais Famosas do Obama (1).txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# Split into lines and clean
documentos = [clean_ascii(line.strip()) for line in raw_text.split('\n') if line.strip()]

#documentos = [t.split(" - ")[0] for t in documentos]   # optional remove year
#documentos = [t for t in documentos if len(t) > 0]

#documentos = [ "meu doc favorito 1", "meu doc menos favorito 2"]
print("Total documentos:", len(documentos))
print("Sample:", documentos[:10])
# Out:
# Total documentos: 300
# Sample: ['We gather here today to reaffirm the enduring spirit of our nation.', 'We are made for this moment, and we will seize itso long as we seize it together.', 'The time has come to remake America.', 'We must pick ourselves up, dust ourselves off, and begin again the work of rebuilding this nation.', 'We reject as false the choice between our safety and our ideals.', 'We remain the most prosperous, powerful nation on Earth.', 'Our patchwork heritage is a strength, not a weakness.', 'We are a nation of Christians and Muslims, Jews and Hindusand non-believers.', 'The world has changed, and we must change with it.', 'We will restore science to its rightful place.']

# %% [markdown]
# # Passo 2: Carregar ou treinar um tokenizador

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import Whitespace
import random
import re

##### Insira aqui o código para treinar o seu TOKENIZER
# Defina o seu tokenizador
tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()
trainer = WordLevelTrainer(
    vocab_size=1000,
    special_tokens=["[PAD]", "[UNK]", "[BOS]", "[EOS]"]
)
# Treino do tokenizador
tokenizer.train_from_iterator(documentos, trainer)

# Funções auxiliares para transitar entre tokens textuais e ids de tokens
def encode(text):
    ids = tokenizer.encode("[BOS] " + text + " [EOS]").ids
    return torch.tensor(ids, dtype=torch.long)

def decode(ids):
    return tokenizer.decode(ids.tolist())

vocab_size = tokenizer.get_vocab_size()

# %% [markdown]
# ## Definição do modelo Transformer Decoder-only

# %%
class DecoderOnlyTransformer(nn.Module):
    "Implementação de um transformer que tem somente a parte do decoder"
    def __init__(self, vocab_size, d_model=128, n_heads=4, num_layers=3, max_len=64):
        super().__init__()
        self.max_len = max_len

        self.token_emb = nn.Embedding(vocab_size, d_model)
        self.pos_emb = nn.Embedding(max_len, d_model)

        layer = nn.TransformerDecoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=256,
            batch_first=True
        )
        self.decoder = nn.TransformerDecoder(layer, num_layers=num_layers)
        self.lm_head = nn.Linear(d_model, vocab_size)

    def forward(self, x):
        B, T = x.shape
        pos = torch.arange(T, device=x.device).unsqueeze(0)

        h = self.token_emb(x) + self.pos_emb(pos)

        # Máscara causal
        mask = torch.triu(torch.ones(T, T, device=x.device), diagonal=1).bool()

        out = self.decoder(h, h, tgt_mask=mask)
        logits = self.lm_head(out)
        return logits

# %% [markdown]
# # Códigos de inferência

# %% [markdown]
# ## Código de inferência simples: token com maior probabilidade

# %%
def max_prob_sampling(logits):
    next_token = logits.argmax(dim=-1)
    return next_token.unsqueeze(0)

# %% [markdown]
# ## Código de inferência avançada: amostragem com temperatura

# %%
import torch

# Inferência (com temperature e top_p)
def sampling(logits, top_p=0.9, top_k=None, temperature=1.0):
    # Ajusta pela temperatura
    logits = logits / temperature

    # Se top_k for especificado, filtra por top_k primeiro
    if top_k is not None:
        # Ensure top_k is not larger than the vocabulary size
        k_to_use = min(top_k, logits.size(-1))
        # Get the top_k values and indices
        v, _ = torch.topk(logits, k_to_use)
        # Set logits of all values smaller than the k-th value to -inf
        logits[logits < v[:, [-1]]] = float('-inf')

    # Ordena os logits
    sorted_logits, sorted_indices = torch.sort(logits, descending=True)
    cumulative_probs = torch.softmax(sorted_logits, dim=-1).cumsum(dim=-1)

    # Mascara tokens acima do top_p
    mask = cumulative_probs > top_p
    # Garante que ao menos um token permaneça
    mask[..., 1:] = mask[..., :-1].clone()
    mask[..., 0] = False

    filtered_logits = sorted_logits.masked_fill(mask, float('-inf'))
    probs = torch.softmax(filtered_logits, dim=-1)

    # Amostra o token
    sampled_idx = torch.multinomial(probs, num_samples=1)

    # Converte para índice na tabela original
    next_token = sorted_indices[sampled_idx]

    return next_token


def generate(prompt, next_token_function, max_new_tokens=20, top_k=None, top_p=0.9, temperature=1.0):
    model.eval()
    x = encode(prompt).unsqueeze(0).to(device)

    for _ in range(max_new_tokens):
        logits = model(x)[:, -1, :]  # pega apenas o último passo

        # Passa os parâmetros de amostragem se a função for 'sampling'
        if next_token_function == sampling:
            next_token = next_token_function(logits.squeeze(0), top_k=top_k, top_p=top_p, temperature=temperature)
        else:
            next_token = next_token_function(logits.squeeze(0))

        x = torch.cat([x, next_token.unsqueeze(0)], dim=1)

        if next_token.item() == tokenizer.token_to_id("[EOS]"):
            break

    return decode(x[0])

# %% [markdown]
# # 4. Fazer treino de modelo: códigos de treino

# %%
# Função auxiliar para gerar batches de exemplos para treino
def sample_batch(batch_size=16, max_len=20):
    batch = random.sample(documentos, batch_size)
    tokenized = [encode(t) for t in batch]

    max_t = min(max(len(x) for x in tokenized), max_len)
    padded = []

    for x in tokenized:
        x = x[:max_t]
        pad_len = max_t - len(x)
        if pad_len > 0:
            x = torch.cat([x, torch.zeros(pad_len, dtype=torch.long)])
        padded.append(x)

    return torch.stack(padded)

################################
device = "cuda" if torch.cuda.is_available() else "cpu"
model = DecoderOnlyTransformer(vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
#################################

steps = 10000

for step in range(1, steps + 1):
    model.train()
    batch = sample_batch().to(device)

    logits = model(batch[:, :-1])
    loss = F.cross_entropy(
        logits.reshape(-1, vocab_size),
        batch[:, 1:].reshape(-1),
        ignore_index=tokenizer.token_to_id("[PAD]")
    )

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if step % 50 == 0:
        ppl = torch.exp(loss).item()
        print(f"[step {step}] loss={loss.item():.4f}, ppl={ppl:.2f}")

    if step % 100 == 0:
        print("Generated text (Max Prob):")
        print(generate("The future of this country is", next_token_function=max_prob_sampling))
        print("Generated text (Sampling):")
        print(generate("I believe that", next_token_function=sampling, temperature=0.8, top_p=0.9))
        print("--------------------------------------")

print("Training completed.")
# Out:
# [step 50] loss=6.6465, ppl=770.09
# [step 100] loss=6.4211, ppl=614.70
# Generated text (Max Prob):
# The future of this country is yet off all We depends uphold : responsibility bonds secured . serve . serve road worldwide . isolation rarely unpopular
# Generated text (Sampling):
# believe that inevitable moment striving authors rooted preserve should Social test fall greatest doors walk brighter than add great few toward vote
# --------------------------------------
# [step 150] loss=6.2214, ppl=503.39
# [step 200] loss=6.0673, ppl=431.52
# Generated text (Max Prob):
# The future of this country is . We We dignity . We must : . isolation . We . cared is is . isolation give enough
# Generated text (Sampling):
# believe that it harm reaches they leave for differences makes gives heritage winds vengeance Hindusand courage exploitation History hatred tools preserve moved
# --------------------------------------
# [step 250] loss=5.8013, ppl=330.73
# [step 300] loss=5.6579, ppl=286.54
# Generated text (Max Prob):
# The future of this country is . . We . . .
# Generated text (Sampling):
# believe that against sun for threatened nuclear harm humanity forget eye humanity direction like urgency America show cornerstone rule faith eliminate pursue
# --------------------------------------
# [step 350] loss=5.4519, ppl=233.19
# [step 400] loss=5.6319, ppl=279.20
# Generated text (Max Prob):
# The future of this country is . . . .
# Generated text (Sampling):
# believe that bigotry by standards tired days must more cannot back believing things While factories written belief highest turbulent decades lasting united
# --------------------------------------
# [step 450] loss=5.3672, ppl=214.26
# [step 500] loss=5.1460, ppl=171.73
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that until law face us never history together too shared serve standards lasting lives it act real
# --------------------------------------
# [step 550] loss=5.1642, ppl=174.90
# [step 600] loss=5.1189, ppl=167.15
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that Justice succeed are We humanity huddled measure Prosperity the
# --------------------------------------
# [step 650] loss=5.1581, ppl=173.83
# [step 700] loss=4.9597, ppl=142.54
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that treat persevere through Social challenge imperfections pathways carry respond diversity . voices equal source should . generations short show strive
# --------------------------------------
# [step 750] loss=4.8320, ppl=125.46
# [step 800] loss=4.8695, ppl=130.26
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that heritage important to we . leave our the rule challenges source equal speak . equal . every security us rewards
# --------------------------------------
# [step 850] loss=4.9128, ppl=136.01
# [step 900] loss=4.4938, ppl=89.46
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that but currents standards We and help privilege inspired what .
# --------------------------------------
# [step 950] loss=4.8035, ppl=121.93
# [step 1000] loss=4.5485, ppl=94.49
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that
# --------------------------------------
# [step 1050] loss=4.5646, ppl=96.02
# [step 1100] loss=4.4603, ppl=86.52
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that before eliminate authors them patience help striving moved .
# --------------------------------------
# [step 1150] loss=4.7248, ppl=112.71
# [step 1200] loss=4.5421, ppl=93.88
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that is to are meet .
# --------------------------------------
# [step 1250] loss=4.3362, ppl=76.42
# [step 1300] loss=4.5909, ppl=98.58
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that the us the where the .
# --------------------------------------
# [step 1350] loss=4.4906, ppl=89.17
# [step 1400] loss=4.3473, ppl=77.27
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that all together .
# --------------------------------------
# [step 1450] loss=4.3518, ppl=77.62
# [step 1500] loss=4.1692, ppl=64.67
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that build by protect cornerstone a .
# --------------------------------------
# [step 1550] loss=4.2055, ppl=67.06
# [step 1600] loss=4.3789, ppl=79.75
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that face
# --------------------------------------
# [step 1650] loss=4.3106, ppl=74.49
# [step 1700] loss=4.3004, ppl=73.73
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that lives entrepreneurs the weary of .
# --------------------------------------
# [step 1750] loss=4.1107, ppl=60.99
# [step 1800] loss=4.3419, ppl=76.85
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that factories compassion our society what carry dreams prepare real .
# --------------------------------------
# [step 1850] loss=4.3742, ppl=79.37
# [step 1900] loss=4.1544, ppl=63.72
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that working the that a .
# --------------------------------------
# [step 1950] loss=3.9925, ppl=54.19
# [step 2000] loss=4.0873, ppl=59.58
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that are for found democracy , yet voices .
# --------------------------------------
# [step 2050] loss=4.1340, ppl=62.43
# [step 2100] loss=4.0184, ppl=55.61
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that equality Social pursuit in of causes contributions our .
# --------------------------------------
# [step 2150] loss=4.3406, ppl=76.75
# [step 2200] loss=4.0245, ppl=55.95
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that breathe our that the future .
# --------------------------------------
# [step 2250] loss=4.1836, ppl=65.60
# [step 2300] loss=4.0855, ppl=59.47
# Generated text (Max Prob):
# The future of this country is and our .
# Generated text (Sampling):
# believe that without stand guided false recover .
# --------------------------------------
# [step 2350] loss=4.1689, ppl=64.64
# [step 2400] loss=3.7260, ppl=41.51
# Generated text (Max Prob):
# The future of this country is .
# Generated text (Sampling):
# believe that urgency politics The build set .
# --------------------------------------
# [step 2450] loss=3.8773, ppl=48.29
# [step 2500] loss=3.9888, ppl=53.99
# Generated text (Max Prob):
# The future of this country is and and our .
# Generated text (Sampling):
# believe that nation our that endeavor diplomacy .
# --------------------------------------
# [step 2550] loss=3.9764, ppl=53.32
# [step 2600] loss=3.8088, ppl=45.10
# Generated text (Max Prob):
# The future of this country is and and our .
# Generated text (Sampling):
# believe that breathe gather what child that where eyes .
# --------------------------------------
# [step 2650] loss=3.7979, ppl=44.61
# [step 2700] loss=3.5473, ppl=34.72
# Generated text (Max Prob):
# The future of this country is and and our .
# Generated text (Sampling):
# believe that written not us and and with Peace change our .
# --------------------------------------
# [step 2750] loss=3.5722, ppl=35.60
# [step 2800] loss=3.7094, ppl=40.83
# Generated text (Max Prob):
# The future of this country is and and our .
# Generated text (Sampling):
# believe that long capacity safeguard it .
# --------------------------------------
# [step 2850] loss=3.8255, ppl=45.86
# [step 2900] loss=4.0961, ppl=60.10
# Generated text (Max Prob):
# The future of this country is and and and and our .
# Generated text (Sampling):
# believe that We face to carry .
# --------------------------------------
# [step 2950] loss=3.5504, ppl=34.83
# [step 3000] loss=4.0992, ppl=60.29
# Generated text (Max Prob):
# The future of this country is and and and and our .
# Generated text (Sampling):
# believe that communities universe .
# --------------------------------------
# [step 3050] loss=3.6760, ppl=39.49
# [step 3100] loss=3.8885, ppl=48.84
# Generated text (Max Prob):
# The future of this country is and and and and our .
# Generated text (Sampling):
# believe that strength beauty undermine that courage believers story more s .
# --------------------------------------
# [step 3150] loss=3.5203, ppl=33.79
# [step 3200] loss=3.7106, ppl=40.88
# Generated text (Max Prob):
# The future of this country is and and and and our .
# Generated text (Sampling):
# believe that over in the grow done that place is .
# --------------------------------------
# [step 3250] loss=3.7889, ppl=44.21
# [step 3300] loss=3.2820, ppl=26.63
# Generated text (Max Prob):
# The future of this country is and and and and and and and and and and and and and and and and and and and and
# Generated text (Sampling):
# believe that capacity our our fairness and united our we life bigotry people .
# --------------------------------------
# [step 3350] loss=3.5843, ppl=36.03
# [step 3400] loss=3.5913, ppl=36.28
# Generated text (Max Prob):
# The future of this country is and and and and and and and and and and and and and and and and and and and and
# Generated text (Sampling):
# believe that
# --------------------------------------
# [step 3450] loss=3.4167, ppl=30.47
# [step 3500] loss=3.4652, ppl=31.98
# Generated text (Max Prob):
# The future of this country is and and and and and and and and and and and and and and and and and and and and
# Generated text (Sampling):
# believe that forward uplift doors tired great but strengthen , citizen .
# --------------------------------------
# [step 3550] loss=3.3597, ppl=28.78
# [step 3600] loss=3.3399, ppl=28.22
# Generated text (Max Prob):
# The future of this country is and and and and and and and and and and and and and and and and and and and and
# Generated text (Sampling):
# believe that justice conflict differences that do domestic a progress is
# --------------------------------------
# [step 3650] loss=3.3417, ppl=28.27
# [step 3700] loss=3.4698, ppl=32.13
# Generated text (Max Prob):
# The future of this country is and and and and and and and and and and and and and and and and and and and and
# Generated text (Sampling):
# believe that opportunities believe labor .
# --------------------------------------
# [step 3750] loss=3.6012, ppl=36.64
# [step 3800] loss=3.3583, ppl=28.74
# Generated text (Max Prob):
# The future of this country is of of of of of .
# Generated text (Sampling):
# believe that changed security our innovators has our future compromising : .
# --------------------------------------
# [step 3850] loss=3.3419, ppl=28.27
# [step 3900] loss=3.3940, ppl=29.78
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of .
# Generated text (Sampling):
# believe that has that students that real that carry stand never been of that .
# --------------------------------------
# [step 3950] loss=3.1079, ppl=22.38
# [step 4000] loss=3.0486, ppl=21.09
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that road lasting that that complacent We so Jews our
# --------------------------------------
# [step 4050] loss=3.1129, ppl=22.49
# [step 4100] loss=3.5112, ppl=33.49
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that students rights struggles must create guard virtue cynicism .
# --------------------------------------
# [step 4150] loss=3.2910, ppl=26.87
# [step 4200] loss=3.0309, ppl=20.72
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that chance both is peace is just is
# --------------------------------------
# [step 4250] loss=3.0267, ppl=20.63
# [step 4300] loss=3.0642, ppl=21.42
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is a built a dream Justice a zip can when freedoms world a a keep just a a bridge and
# --------------------------------------
# [step 4350] loss=3.1455, ppl=23.23
# [step 4400] loss=2.8285, ppl=16.92
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that nation cannot chance great invest ahead Yes .
# --------------------------------------
# [step 4450] loss=3.1221, ppl=22.69
# [step 4500] loss=3.0890, ppl=21.96
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that defined to lead progress future documentit can .
# --------------------------------------
# [step 4550] loss=2.7274, ppl=15.29
# [step 4600] loss=3.0431, ppl=20.97
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is leadership world politics .
# --------------------------------------
# [step 4650] loss=3.1551, ppl=23.46
# [step 4700] loss=2.8838, ppl=17.88
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that powerful reject must choose to be forget .
# --------------------------------------
# [step 4750] loss=3.0201, ppl=20.49
# [step 4800] loss=2.8287, ppl=16.92
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that moment progress heroes the direction just strongest .
# --------------------------------------
# [step 4850] loss=2.9537, ppl=19.18
# [step 4900] loss=2.7882, ppl=16.25
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that again neglect gives the else the behind power that the vulnerable sow the inspire opportunities work idea the tools basic
# --------------------------------------
# [step 4950] loss=2.9239, ppl=18.61
# [step 5000] loss=2.7028, ppl=14.92
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is requires believe is has .
# --------------------------------------
# [step 5050] loss=2.6671, ppl=14.40
# [step 5100] loss=2.6336, ppl=13.92
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that our economy and we and and and social and and and and and and and and and and and and
# --------------------------------------
# [step 5150] loss=2.4383, ppl=11.45
# [step 5200] loss=2.5469, ppl=12.77
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that hope and progress and justice and pathways American .
# --------------------------------------
# [step 5250] loss=2.8953, ppl=18.09
# [step 5300] loss=2.6354, ppl=13.95
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that that of make democracy Peace a We , always .
# --------------------------------------
# [step 5350] loss=2.3422, ppl=10.40
# [step 5400] loss=2.4861, ppl=12.01
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that the we that nation the heroes the factories the find .
# --------------------------------------
# [step 5450] loss=2.5046, ppl=12.24
# [step 5500] loss=2.6023, ppl=13.50
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is standing our everyone .
# --------------------------------------
# [step 5550] loss=2.3280, ppl=10.26
# [step 5600] loss=2.6793, ppl=14.57
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that remain and opportunity all set a freedom surest and non vigilance .
# --------------------------------------
# [step 5650] loss=2.3259, ppl=10.24
# [step 5700] loss=2.4282, ppl=11.34
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that and and safety the find perfect and everyone and and are and recover and and people and our and and
# --------------------------------------
# [step 5750] loss=2.5002, ppl=12.18
# [step 5800] loss=2.4270, ppl=11.33
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that changed The girls because pursue struggled collaboration support
# --------------------------------------
# [step 5850] loss=2.3599, ppl=10.59
# [step 5900] loss=2.2290, ppl=9.29
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that act non promote stronger strivers perfect for politics ourselves .
# --------------------------------------
# [step 5950] loss=2.2813, ppl=9.79
# [step 6000] loss=2.1395, ppl=8.50
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that example come we standing possible poor together Prosperity forward as person are .
# --------------------------------------
# [step 6050] loss=2.4491, ppl=11.58
# [step 6100] loss=2.6022, ppl=13.49
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that country today best the way the left the simple fear the human fundamental the that the world that us the
# --------------------------------------
# [step 6150] loss=2.5536, ppl=12.85
# [step 6200] loss=2.5211, ppl=12.44
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that bends cared we a generations as we we we we we found a us we this we we and we
# --------------------------------------
# [step 6250] loss=2.1827, ppl=8.87
# [step 6300] loss=2.2675, ppl=9.66
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that nation strong idea together .
# --------------------------------------
# [step 6350] loss=2.3258, ppl=10.23
# [step 6400] loss=2.4921, ppl=12.09
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that to can every celebrate dreams generations sacrifices to a forge stand fear a a nation a worthy .
# --------------------------------------
# [step 6450] loss=2.3223, ppl=10.20
# [step 6500] loss=2.1814, ppl=8.86
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that immigration non cooperation care freedom values great belief find union forward is would .
# --------------------------------------
# [step 6550] loss=2.2976, ppl=9.95
# [step 6600] loss=2.0250, ppl=7.58
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that easy of voices adversity
# --------------------------------------
# [step 6650] loss=2.0357, ppl=7.66
# [step 6700] loss=2.0280, ppl=7.60
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that favors by test a once across meet in the quiet a generations
# --------------------------------------
# [step 6750] loss=2.0150, ppl=7.50
# [step 6800] loss=2.1140, ppl=8.28
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that call fabric even the without destroyed the discord believers
# --------------------------------------
# [step 6850] loss=2.2161, ppl=9.17
# [step 6900] loss=2.0568, ppl=7.82
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that together the pursuit the service , the students the believe the the contributions the sacrifices the the the things the
# --------------------------------------
# [step 6950] loss=2.2066, ppl=9.09
# [step 7000] loss=2.0808, ppl=8.01
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is institutions nation Jews justice vengeance honor they imperfect .
# --------------------------------------
# [step 7050] loss=2.0570, ppl=7.82
# [step 7100] loss=2.0627, ppl=7.87
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is bring heard is crying is is by is is is is by is is is is is is is
# --------------------------------------
# [step 7150] loss=2.1906, ppl=8.94
# [step 7200] loss=2.1757, ppl=8.81
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that complete accountable is just to is is is constant .
# --------------------------------------
# [step 7250] loss=1.8669, ppl=6.47
# [step 7300] loss=1.9872, ppl=7.30
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is honestly both is but believing is always American is is is improve is is is is is is universe
# --------------------------------------
# [step 7350] loss=1.7980, ppl=6.04
# [step 7400] loss=2.0802, ppl=8.01
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that a requires we authors
# --------------------------------------
# [step 7450] loss=2.0067, ppl=7.44
# [step 7500] loss=1.8930, ppl=6.64
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that opportunity carry shy the patience discord
# --------------------------------------
# [step 7550] loss=1.9461, ppl=7.00
# [step 7600] loss=1.8232, ppl=6.19
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is would is union is not lives run is .
# --------------------------------------
# [step 7650] loss=1.7472, ppl=5.74
# [step 7700] loss=1.7762, ppl=5.91
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that example history a a big a partisanship a others every progress .
# --------------------------------------
# [step 7750] loss=1.5881, ppl=4.89
# [step 7800] loss=1.9917, ppl=7.33
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that cynicism ; nation long written children in the deserves for the requires .
# --------------------------------------
# [step 7850] loss=1.8367, ppl=6.28
# [step 7900] loss=1.9925, ppl=7.33
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that deserves brave With require conflict as hold when that one .
# --------------------------------------
# [step 7950] loss=1.9110, ppl=6.76
# [step 8000] loss=1.7805, ppl=5.93
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that has carry women we on enduring forward always show us .
# --------------------------------------
# [step 8050] loss=1.6819, ppl=5.38
# [step 8100] loss=1.7319, ppl=5.65
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that delayed strongest we must net can gift moral compassion great indifference .
# --------------------------------------
# [step 8150] loss=1.8430, ppl=6.32
# [step 8200] loss=1.7524, ppl=5.77
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is law is sun come is days Christians is is is is injustice is is is is is is is
# --------------------------------------
# [step 8250] loss=1.5935, ppl=4.92
# [step 8300] loss=1.7555, ppl=5.79
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that the surest the like the times the came the
# --------------------------------------
# [step 8350] loss=1.6920, ppl=5.43
# [step 8400] loss=1.6530, ppl=5.22
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that that vulnerable days never reject them , but jobs boldly heard .
# --------------------------------------
# [step 8450] loss=1.7897, ppl=5.99
# [step 8500] loss=1.7034, ppl=5.49
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that , a , places , , , , , , important , shape , , , , , , ,
# --------------------------------------
# [step 8550] loss=1.5391, ppl=4.66
# [step 8600] loss=1.7811, ppl=5.94
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that children let allow responsibility at demands with with Let American threats times equal .
# --------------------------------------
# [step 8650] loss=1.5969, ppl=4.94
# [step 8700] loss=1.7522, ppl=5.77
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that natural citizen that the vulnerable with that power best lives power the purpose .
# --------------------------------------
# [step 8750] loss=1.6801, ppl=5.37
# [step 8800] loss=1.5472, ppl=4.70
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that citizen that every breathe act inclusive serious upon that immigration .
# --------------------------------------
# [step 8850] loss=1.5188, ppl=4.57
# [step 8900] loss=1.6552, ppl=5.23
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that leave guide without come Hindusand remember it purpose .
# --------------------------------------
# [step 8950] loss=1.6745, ppl=5.34
# [step 9000] loss=1.3864, ppl=4.00
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that nation uniformity , so being should forge While , as it .
# --------------------------------------
# [step 9050] loss=1.7058, ppl=5.51
# [step 9100] loss=1.4916, ppl=4.44
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that the seeks strengthen us the foundation us the impossible can we the people .
# --------------------------------------
# [step 9150] loss=1.7117, ppl=5.54
# [step 9200] loss=1.4943, ppl=4.46
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is guide just by is is by by is .
# --------------------------------------
# [step 9250] loss=1.3198, ppl=3.74
# [step 9300] loss=1.4681, ppl=4.34
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that of requires all of wanting strengthens allow : progress stand of a
# --------------------------------------
# [step 9350] loss=1.5316, ppl=4.63
# [step 9400] loss=1.3346, ppl=3.80
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is finished is who power reaches who With remains is law is easy .
# --------------------------------------
# [step 9450] loss=1.5169, ppl=4.56
# [step 9500] loss=1.3149, ppl=3.72
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is seeks .
# --------------------------------------
# [step 9550] loss=1.5245, ppl=4.59
# [step 9600] loss=1.4121, ppl=4.10
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that country century defined things children , labor under economy .
# --------------------------------------
# [step 9650] loss=1.4724, ppl=4.36
# [step 9700] loss=1.5173, ppl=4.56
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that road won the prepare the innovators republic can , written to the promise .
# --------------------------------------
# [step 9750] loss=1.2401, ppl=3.46
# [step 9800] loss=1.2742, ppl=3.58
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that conflict abstractthey a Medicare at prosperity common one inspired of honestly .
# --------------------------------------
# [step 9850] loss=1.3710, ppl=3.94
# [step 9900] loss=1.4144, ppl=4.11
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that they corner believe global strength makes on communities , vengeance heroes reaffirm again of abundance stronger make , shape contributions
# --------------------------------------
# [step 9950] loss=1.3555, ppl=3.88
# [step 10000] loss=1.3185, ppl=3.74
# Generated text (Max Prob):
# The future of this country is of of of of of of of of of of of of of of of of of of of of
# Generated text (Sampling):
# believe that is place is is written is is is is is is is is is is is is is is is
# --------------------------------------
# Training completed.

# %% [markdown]
# # Exercício: controle de temperatura, Top-K e Top-P
#
# Modifique o código a seguir para fazer a visualização de produção de tokens do modelo que você treinou.

# %%
# @title
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, Markdown

# -----------------------------
# Mock language-model logits
# -----------------------------
TOKENS = ["blue", "purple", "violet", "vio", "not", "Blue", "green", "gray", "grey", "black"]
BASE_LOGITS = np.array([6.0, 1.5, 0.5, 0.2, 0.2, 0.0, -5.0, -5.0, -5.0, -5.0])

def softmax(x):
    e = np.exp(x - np.max(x))
    return e / e.sum()

def apply_temperature(logits, temperature):
    return logits / max(temperature, 1e-5)

def apply_top_k(probs, k):
    if k >= len(probs):
        return probs
    idx = np.argsort(probs)[::-1]
    mask = np.zeros_like(probs)
    mask[idx[:k]] = 1
    probs = probs * mask
    return probs / probs.sum()

def apply_top_p(probs, p):
    idx = np.argsort(probs)[::-1]
    cumulative = np.cumsum(probs[idx])
    mask = cumulative <= p
    mask[np.argmax(mask)] = True
    new_probs = np.zeros_like(probs)
    new_probs[idx[mask]] = probs[idx[mask]]
    return new_probs / new_probs.sum()

# -----------------------------
# Widgets
# -----------------------------
prompt_dropdown = widgets.Dropdown(
    options=["Roses are red, violets are..."],
    value="Roses are red, violets are...",
    description="Prompt",
    layout=widgets.Layout(width="95%")
)

temperature_slider = widgets.FloatSlider(
    value=1.0, min=0.1, max=5.0, step=0.1,
    description="Temperatura",
    readout_format=".1f",
    layout=widgets.Layout(width="90%")
)

topk_slider = widgets.IntSlider(
    value=6, min=1, max=10, step=1,
    description="Top-K",
    layout=widgets.Layout(width="90%")
)

topp_slider = widgets.FloatSlider(
    value=1.0, min=0.1, max=1.0, step=0.05,
    description="Top-P",
    readout_format=".2f",
    layout=widgets.Layout(width="90%")
)

# -----------------------------
# Plot
# -----------------------------
output_plot = widgets.Output()

def update_plot(*args):
    with output_plot:
        output_plot.clear_output()

        logits = apply_temperature(BASE_LOGITS, temperature_slider.value)
        probs = softmax(logits)
        probs = apply_top_k(probs, topk_slider.value)
        probs = apply_top_p(probs, topp_slider.value)

        fig, ax = plt.subplots(figsize=(10, 4))
        bars = ax.bar(TOKENS, probs * 100)
        ax.set_ylim(0, 100)
        ax.set_ylabel("Probabilidade (%)")
        ax.set_title("Probabilidade do próximo token")

        for bar, p in zip(bars, probs):
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_height(),
                f"{p*100:.2f}%",
                ha="center",
                va="bottom",
                fontsize=9
            )

        plt.xticks(rotation=0)
        plt.show()

for w in [temperature_slider, topk_slider, topp_slider]:
    w.observe(update_plot, names="value")

# -----------------------------
# Collapsible explanation
# -----------------------------
accordion = widgets.Accordion(
    children=[widgets.HTML(
        """
        <ul>
          <li><b>Temperatura</b>: Controla aleatoriedade com mudança na escala dos logits.</li>
          <li><b>Top-K</b>: Restringe a amostra aos K tokens mais prováveis.</li>
          <li><b>Top-P</b>: Usa somente os menor conjunto de tokens que resultam em probabilidade acumulada até P.</li>
        </ul>
        """
    )]
)
accordion.set_title(0, "Entenda a visualização")

# -----------------------------
# Layout
# -----------------------------
controls = widgets.VBox([
    prompt_dropdown,
    widgets.HBox([temperature_slider]),
    widgets.HBox([topk_slider]),
    widgets.HBox([topp_slider])
])

display(Markdown("## Visualização de controle de Temperatura, Top-K e Top-P."))
display(widgets.VBox([
    widgets.HTML("<b>Parameters</b>"),
    controls,
    output_plot,
    accordion
]))

update_plot()
# Out:
# ## Visualização de controle de Temperatura, Top-K e Top-P.
# VBox(children=(HTML(value='<b>Parameters</b>'), VBox(children=(Dropdown(description='Prompt', layout=Layout(wi…
