# %% [markdown]
# <a href="https://colab.research.google.com/github/ferdinandrafols/IA_LLMs/blob/main/DiscursosObamaScript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import json
from urllib.parse import urljoin

BASE_LIST_URL = "https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks"
BASE_DOMAIN = "https://obamawhitehouse.archives.gov"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; ObamaCorpusBot/1.0; +https://example.com/bot)"
}

def get_soup(url):
    resp = requests.get(url, headers=HEADERS, timeout=20)
    resp.raise_for_status()
    return BeautifulSoup(resp.text, "html.parser")

def extract_speech_links_from_page(list_url):
    """
    Dada uma página da lista de discursos,
    retorna uma lista de URLs completas para cada discurso
    + o próprio soup para paginação.
    """
    soup = get_soup(list_url)
    links = []

    # Os discursos geralmente aparecem em .view-content .views-row
    for row in soup.select(".view-content .views-row"):
        a = row.find("a", href=True)
        if not a:
            continue
        href = a["href"]
        full_url = urljoin(BASE_DOMAIN, href)
        links.append(full_url)

    return links, soup

def find_next_page(soup):
    """
    Tenta encontrar link de próxima página na paginação.
    Isso pode precisar de ajuste se o HTML mudar.
    """
    # Padrão comum: link com título "Go to next page"
    next_link = soup.find("a", title="Go to next page")
    if next_link and next_link.get("href"):
        return urljoin(BASE_DOMAIN, next_link["href"])

    # fallback: procurar algo com 'next' na paginação
    pager_next = soup.select_one(".pager-next a, li.next a")
    if pager_next and pager_next.get("href"):
        return urljoin(BASE_DOMAIN, pager_next["href"])

    return None

def extract_title(soup):
    """
    Tenta extrair o título do discurso.
    Usa vários seletores comuns como fallback.
    """
    # Padrões comuns do site
    title = None
    h1 = soup.find("h1", class_="page-title") or \
         soup.find("h1", id="page-title") or \
         soup.find("h1")
    if h1 and h1.get_text(strip=True):
        title = h1.get_text(strip=True)
    else:
        # fallback: <title> da página
        if soup.title and soup.title.get_text(strip=True):
            title = soup.title.get_text(strip=True)

    return title or ""

def extract_date(soup):
    """
    Tenta extrair a data do discurso.
    Isso pode variar de acordo com o template.
    """
    # Caso 1: span com classe de data
    date_span = soup.find("span", class_="date-display-single")
    if date_span and date_span.get_text(strip=True):
        return date_span.get_text(strip=True)

    # Caso 2: time tag
    time_tag = soup.find("time")
    if time_tag and time_tag.get_text(strip=True):
        return time_tag.get_text(strip=True)

    # Caso 3: div/linha de metadados
    meta_div = soup.find(class_="submitted") or soup.find("p", class_="datestamp")
    if meta_div and meta_div.get_text(strip=True):
        txt = meta_div.get_text(" ", strip=True)
        return txt

    # Se nada der certo, vazio (ainda assim o JSON fica usável)
    return ""

def extract_main_text_from_speech(soup):
    """
    Extrai o texto principal do discurso da página HTML.
    Pode ser necessário ajustar se o HTML do site mudar.
    """
    # Muitas páginas usam div.field-item para o conteúdo do discurso
    content_divs = soup.select(".field-item.even, .field-item.odd")
    if not content_divs:
        # fallback: tentar <article>
        article = soup.find("article")
        if article:
            text = article.get_text(separator="\n")
        else:
            # fallback final: texto da página toda
            text = soup.get_text(separator="\n")
    else:
        text_parts = [div.get_text(separator="\n") for div in content_divs]
        text = "\n".join(text_parts)

    # Limpeza básica
    text = re.sub(r"\r", "\n", text)
    text = re.sub(r"\n{2,}", "\n", text)
    text = text.strip()

    return text

def extract_speech_data(url):
    """
    Dado a URL de um discurso, retorna um dict:
    {
        "title": ...,
        "date": ...,
        "url": ...,
        "text": ...
    }
    """
    soup = get_soup(url)
    title = extract_title(soup)
    date = extract_date(soup)
    text = extract_main_text_from_speech(soup)

    return {
        "title": title,
        "date": date,
        "url": url,
        "text": text
    }

def crawl_all_obama_speeches(max_pages=None):
    """
    Percorre todas as páginas de listagem de discursos.
    max_pages: se for None, vai até acabar.
    """
    all_links = []
    page_url = BASE_LIST_URL
    page_count = 0

    while page_url:
        page_count += 1
        print(f"[INFO] Coletando página {page_count}: {page_url}")

        links, soup = extract_speech_links_from_page(page_url)
        print(f"  -> {len(links)} discursos encontrados nesta página.")
        all_links.extend(links)

        if max_pages is not None and page_count >= max_pages:
            break

        next_url = find_next_page(soup)
        if not next_url:
            print("[INFO] Não há próxima página. Fim da paginação.")
            break

        page_url = next_url
        time.sleep(1.0)  # educado com o servidor

    # Remove duplicados preservando a ordem
    seen = set()
    unique_links = []
    for url in all_links:
        if url not in seen:
            seen.add(url)
            unique_links.append(url)

    print(f"[INFO] Total de discursos únicos: {len(unique_links)}")
    return unique_links

def build_obama_jsonl_corpus(output_path="obama_speeches.jsonl",
                             log_every=20,
                             max_pages=None):
    """
    Gera um arquivo JSONL onde cada linha é:
    {"title": ..., "date": ..., "url": ..., "text": ...}
    """
    speech_links = crawl_all_obama_speeches(max_pages=max_pages)

    total_docs = 0
    with open(output_path, "w", encoding="utf-8") as f_out:
        for i, url in enumerate(speech_links, start=1):
            try:
                print(f"[INFO] ({i}/{len(speech_links)}) Processando discurso: {url}")
                data = extract_speech_data(url)

                # Se quiser descartar páginas vazias:
                if not data["text"]:
                    print("  -> texto vazio, pulando.")
                    continue

                line = json.dumps(data, ensure_ascii=False)
                f_out.write(line + "\n")
                total_docs += 1

                if i % log_every == 0:
                    print(f"  -> discursos acumulados escritos: {total_docs}")

                time.sleep(0.5)  # evita sobrecarga no servidor
            except Exception as e:
                print(f"[ERRO] Falha ao processar {url}: {e}")
                continue

    print(f"[FIM] Corpus JSONL gerado em '{output_path}' com {total_docs} discursos.")

if __name__ == "__main__":
    # Para testar com poucas páginas, use por exemplo:
    # build_obama_jsonl_corpus(max_pages=2)
    build_obama_jsonl_corpus()
# Out:
# [INFO] Coletando página 1: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 2: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=1
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 3: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=2
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 4: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=3
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 5: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=4
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 6: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=5
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 7: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=6
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 8: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=7
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 9: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=8
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 10: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=9
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 11: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=10
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 12: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=11
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 13: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=12
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 14: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=13
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 15: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=14
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 16: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=15
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 17: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=16
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 18: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=17
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 19: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=18
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 20: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=19
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 21: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=20
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 22: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=21
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 23: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=22
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 24: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=23
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 25: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=24
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 26: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=25
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 27: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=26
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 28: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=27
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 29: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=28
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 30: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=29
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 31: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=30
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 32: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=31
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 33: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=32
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 34: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=33
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 35: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=34
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 36: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=35
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 37: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=36
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 38: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=37
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 39: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=38
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 40: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=39
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 41: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=40
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 42: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=41
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 43: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=42
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 44: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=43
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 45: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=44
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 46: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=45
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 47: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=46
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 48: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=47
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 49: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=48
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 50: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=49
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 51: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=50
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 52: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=51
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 53: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=52
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 54: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=53
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 55: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=54
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 56: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=55
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 57: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=56
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 58: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=57
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 59: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=58
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 60: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=59
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 61: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=60
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 62: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=61
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 63: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=62
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 64: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=63
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 65: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=64
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 66: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=65
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 67: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=66
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 68: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=67
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 69: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=68
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 70: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=69
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 71: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=70
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 72: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=71
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 73: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=72
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 74: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=73
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 75: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=74
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 76: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=75
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 77: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=76
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 78: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=77
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 79: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=78
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 80: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=79
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 81: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=80
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 82: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=81
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 83: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=82
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 84: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=83
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 85: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=84
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 86: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=85
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 87: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=86
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 88: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=87
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 89: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=88
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 90: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=89
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 91: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=90
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 92: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=91
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 93: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=92
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 94: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=93
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 95: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=94
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 96: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=95
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 97: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=96
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 98: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=97
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 99: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=98
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 100: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=99
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 101: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=100
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 102: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=101
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 103: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=102
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 104: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=103
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 105: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=104
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 106: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=105
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 107: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=106
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 108: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=107
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 109: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=108
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 110: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=109
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 111: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=110
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 112: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=111
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 113: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=112
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 114: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=113
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 115: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=114
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 116: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=115
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 117: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=116
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 118: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=117
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 119: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=118
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 120: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=119
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 121: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=120
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 122: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=121
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 123: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=122
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 124: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=123
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 125: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=124
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 126: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=125
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 127: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=126
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 128: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=127
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 129: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=128
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 130: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=129
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 131: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=130
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 132: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=131
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 133: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=132
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 134: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=133
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 135: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=134
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 136: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=135
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 137: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=136
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 138: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=137
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 139: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=138
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 140: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=139
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 141: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=140
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 142: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=141
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 143: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=142
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 144: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=143
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 145: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=144
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 146: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=145
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 147: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=146
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 148: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=147
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 149: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=148
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 150: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=149
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 151: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=150
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 152: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=151
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 153: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=152
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 154: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=153
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 155: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=154
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 156: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=155
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 157: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=156
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 158: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=157
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 159: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=158
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 160: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=159
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 161: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=160
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 162: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=161
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 163: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=162
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 164: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=163
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 165: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=164
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 166: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=165
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 167: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=166
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 168: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=167
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 169: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=168
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 170: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=169
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 171: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=170
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 172: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=171
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 173: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=172
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 174: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=173
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 175: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=174
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 176: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=175
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 177: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=176
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 178: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=177
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 179: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=178
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 180: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=179
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 181: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=180
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 182: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=181
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 183: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=182
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 184: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=183
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 185: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=184
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 186: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=185
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 187: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=186
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 188: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=187
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 189: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=188
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 190: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=189
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 191: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=190
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 192: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=191
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 193: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=192
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 194: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=193
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 195: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=194
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 196: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=195
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 197: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=196
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 198: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=197
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 199: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=198
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 200: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=199
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 201: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=200
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 202: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=201
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 203: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=202
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 204: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=203
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 205: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=204
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 206: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=205
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 207: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=206
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 208: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=207
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 209: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=208
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 210: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=209
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 211: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=210
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 212: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=211
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 213: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=212
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 214: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=213
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 215: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=214
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 216: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=215
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 217: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=216
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 218: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=217
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 219: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=218
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 220: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=219
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 221: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=220
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 222: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=221
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 223: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=222
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 224: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=223
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 225: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=224
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 226: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=225
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 227: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=226
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 228: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=227
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 229: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=228
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 230: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=229
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 231: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=230
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 232: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=231
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 233: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=232
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 234: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=233
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 235: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=234
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 236: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=235
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 237: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=236
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 238: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=237
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 239: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=238
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 240: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=239
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 241: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=240
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 242: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=241
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 243: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=242
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 244: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=243
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 245: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=244
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 246: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=245
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 247: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=246
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 248: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=247
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 249: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=248
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 250: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=249
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 251: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=250
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 252: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=251
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 253: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=252
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 254: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=253
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 255: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=254
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 256: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=255
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 257: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=256
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 258: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=257
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 259: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=258
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 260: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=259
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 261: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=260
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 262: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=261
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 263: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=262
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 264: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=263
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 265: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=264
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 266: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=265
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 267: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=266
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 268: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=267
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 269: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=268
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 270: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=269
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 271: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=270
#   -> 10 discursos encontrados nesta página.
# [INFO] Coletando página 272: https://obamawhitehouse.archives.gov/briefing-room/speeches-and-remarks?term_node_tid_depth=31&page=271
#   -> 10 discursos encontrados nesta página.
# ...
# [INFO] (1066/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/20/remarks-president-national-medals-science-and-national-medals-technology
# [INFO] (1067/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/19/remarks-prepared-delivery-dr-jill-biden-global-entrepreneurship-summit-w
# [INFO] (1068/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/19/remarks-president-connected-superintendents-summit
# [INFO] (1069/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/19/remarks-president-bill-signing
# [INFO] (1070/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/18/remarks-senior-administration-officials-conference-call-vice-presidents-
# [INFO] (1071/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/18/remarks-president-meeting-national-security-and-public-health-teams-ebol
# [INFO] (1072/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/16/remarks-president-obama-g20-press-conference-november-16-2014
# [INFO] (1073/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/15/weekly-address-open-enrollment-starts-today
# [INFO] (1074/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/15/remarks-president-obama-university-queensland
# [INFO] (1075/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/14/remarks-president-obama-and-daw-aung-san-suu-kyi-burma-joint-press-confe
# [INFO] (1076/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/14/remarks-president-obama-young-southeast-asian-leaders-initiative-town-ha
# [INFO] (1077/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/14/remarks-president-obama-after-civil-society-roundtable
# [INFO] (1078/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/13/remarks-president-obama-after-bilateral-meeting-president-thein-sein-bur
# [INFO] (1079/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/13/remarks-president-obama-after-roundtable-parliamentary-resource-center-n
# [INFO] (1080/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/13/remarks-president-obama-us-asean-summit-meeting
#   -> discursos acumulados escritos: 1080
# [INFO] (1081/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/12/remarks-president-obama-and-president-xi-jinping-joint-press-conference
# [INFO] (1082/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/12/toast-remarks-president-obama-luncheon-president-xi-china
# [INFO] (1083/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/12/remarks-president-obama-bilateral-meeting-president-xi-china
# [INFO] (1084/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/11/remarks-president-obama-apec-plenary-session-one
# [INFO] (1085/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-first-lady-doc-mcstuffins-screening-military-children-honor-vete
# [INFO] (1086/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-first-lady-national-arts-and-humanities-youth-program-awards
# [INFO] (1087/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-first-lady-women-veterans-career-development-forum
# [INFO] (1088/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-president-obama-and-prime-minister-abbott-australia-after-bilate
# [INFO] (1089/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-president-obama-apec-ceo-summit
# [INFO] (1090/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-president-tpp-meeting
# [INFO] (1091/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/10/remarks-president-obama-and-president-widodo-indonesia-bilateral-meeting
# [INFO] (1092/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/09/remarks-president-nomination-loretta-lynch-attorney-general
# [INFO] (1093/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/08/weekly-address-veterans-day-lets-honor-our-veterans
# [INFO] (1094/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/07/remarks-president-meeting-congressional-leadership
# [INFO] (1095/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/07/remarks-president-cabinet-meeting
# [INFO] (1096/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/06/remarks-president-salute-troops-concert-white-house
# [INFO] (1097/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/06/remarks-president-medal-honor-presentation-first-lieutenant-alonzo-h-cus
# [INFO] (1098/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/06/remarks-first-lady-salute-troops-workshop
# [INFO] (1099/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/05/remarks-president-press-conference
# [INFO] (1100/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/03/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
#   -> discursos acumulados escritos: 1100
# [INFO] (1101/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/02/remarks-president-rally-tom-wolf-governor
# [INFO] (1102/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/02/remarks-president-rally-governor-dan-malloy-bridgeport-connecticut
# [INFO] (1103/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/01/remarks-president-rally-gary-peters-and-mark-schauer-detroit-michigan
# [INFO] (1104/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/01/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
# [INFO] (1105/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/11/01/weekly-address-it-s-time-help-women-and-working-families
# [INFO] (1106/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/31/statement-nsc-spokesperson-bernadette-meehan-anticipated-separatist-elec
# [INFO] (1107/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/31/remarks-president-women-and-economy-providence-ri
# [INFO] (1108/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/30/remarks-president-michaud-governor-rally
# [INFO] (1109/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/30/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
# [INFO] (1110/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/30/remarks-first-lady-grassroots-campaign-event-democratic-candidate-gove-0
# [INFO] (1111/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/29/remarks-president-american-health-care-workers-fighting-ebola
# [INFO] (1112/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/28/remarks-president-burke-governor-rally
# [INFO] (1113/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/28/remarks-president-ebola
# [INFO] (1114/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/25/weekly-address-focused-fight-against-ebola
# [INFO] (1115/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/24/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
# [INFO] (1116/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/24/remarks-first-lady-grassroots-campaign-event-democratic-candidate-senate
# [INFO] (1117/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/22/remarks-president-us-governments-ebola-response-and-shooting-incident-ca
# [INFO] (1118/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/22/remarks-prepared-delivery-dr-jill-biden-women-world-texas-military-famil
# [INFO] (1119/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/21/remarks-first-lady-grassroots-campaign-event-democratic-candidate-senate
# [INFO] (1120/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/21/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
#   -> discursos acumulados escritos: 1120
# [INFO] (1121/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/20/remarks-president-dnc-event-chicago-il
# [INFO] (1122/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/19/remarks-president-anthony-brown-governor-rally
# [INFO] (1123/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/19/remarks-president-overflow-rally
# [INFO] (1124/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/18/remarks-first-lady-grassroots-campaign-event-democratic-candidate-gove-0
# [INFO] (1125/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/18/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
# [INFO] (1126/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/18/weekly-address-what-you-need-know-about-ebola
# [INFO] (1127/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/17/remarks-president-protecting-american-consumers
# [INFO] (1128/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/16/remarks-president-after-meeting-governments-response-ebola-october-16-20
# [INFO] (1129/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/15/remarks-president-after-meeting-governments-response-ebola
# [INFO] (1130/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/15/remarks-first-lady-grassroots-campaign-event-democratic-candidate-govern
# [INFO] (1131/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/14/remarks-president-after-meeting-chiefs-defense
# [INFO] (1132/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/14/remarks-first-lady-white-house-kitchen-garden-harvest
# [INFO] (1133/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/11/remarks-president-dnc-event-san-francisco-ca
# [INFO] (1134/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/11/remarks-first-lady-bruce-braley-senate-rally-des-moines-iowa
# [INFO] (1135/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/11/weekly-address-america-place-where-hard-work-should-be-rewarded
# [INFO] (1136/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/10/remarks-president-designation-san-gabriel-mountains-national-monument
# [INFO] (1137/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/10/remarks-first-lady-schauer-governor-and-peters-senate-rally
# [INFO] (1138/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/09/remarks-by-president-dnc-event-los-angeles-ca
# [INFO] (1139/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/09/remarks-president-town-hall-innovation-los-angeles-california
# [INFO] (1140/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/08/remarks-first-lady-conclusion-fashion-education-workshop
#   -> discursos acumulados escritos: 1140
# [INFO] (1141/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/08/remarks-president-pentagon
# [INFO] (1142/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/08/remarks-president-conference-call-state-and-local-officials-ebola
# [INFO] (1143/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/08/remarks-first-lady-fashion-education-workshop
# [INFO] (1144/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/07/remarks-first-lady-grassroots-campaign-event-governor-pat-quinn-chicago-
# [INFO] (1145/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/07/remarks-president-dscc-event
# [INFO] (1146/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/07/remarks-president-dnc-event-new-york
# [INFO] (1147/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/07/remarks-first-lady-grassroots-campaign-event-candidate-mary-burke-madiso
# [INFO] (1148/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/06/remarks-president-dnc-event
# [INFO] (1149/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/06/remarks-president-after-meeting-ebola
# [INFO] (1150/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/05/remarks-president-american-veterans-disabled-life-memorial-dedication
# [INFO] (1151/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/04/weekly-address-we-do-better-when-middle-class-does-better
# [INFO] (1152/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/03/remarks-first-lady-michelle-obama-michaud-governor-rally
# [INFO] (1153/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/03/remarks-president-town-hall-manufacturing
# [INFO] (1154/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/03/remarks-first-lady-michelle-obama-martha-coakley-governor-rally
# [INFO] (1155/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/03/remarks-vice-president-john-f-kennedy-forum
# [INFO] (1156/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/02/remarks-president-congressional-hispanic-caucus-institute-gala
# [INFO] (1157/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/02/remarks-president-economy-northwestern-university
# [INFO] (1158/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/01/remarks-president-honoring-mls-cup-champion-sporting-kc
# [INFO] (1159/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/10/01/remarks-president-obama-and-prime-minister-netanyahu-israel-bilateral-me
# [INFO] (1160/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/09/30/remarks-president-obama-and-prime-minister-narendra-modi-india-after-bil
#   -> discursos acumulados escritos: 1160
# [INFO] (1161/4718) Processando discurso: https://obamawhitehouse.archives.gov/the-press-office/2014/09/30/remarks-first-lady-annual-cooper-hewitt-luncheon
