# %% [markdown]
# <a href="https://colab.research.google.com/github/ferdinandrafols/IA_LLMs/blob/main/Aula02_12_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mini_llm.embedding.weight
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1763402355.py in <cell line: 0>()
# ----> 1 mini_llm.embedding.weight
#
# NameError: name 'mini_llm' is not defined

# %%
class MeuBlocoDecoder(nn.Module):
  def __init__(self, model_dim, vocab_size, n_heads, n_layers):
    super().__init__()
    self.norm1 = nn.LayerNorm(model_dim)
    self.norm2 = nn.LayerNorm(model_dim)
    self.norm3 = nn.LayerNorm(model_dim)

    self.att_cros = nn.MultiheadAttention(model_dim, n_heads)
    self.att_self = nn.MultiheadAttention(model_dim, n_heads)
    self.feed_forward = nn.Sequential(
        nn.Linear(model_dim, 2 * model_dim),
        nn.ReLU(),
        nn.Linear(2 * model_dim, model_dim),)
    self.lm_head = nn.Linear(model_dim, vocab_size)

    def forward(self, x, encoder_output):
      x = self.embedding(x)

      rest_att_self = self.att_self(x, x, x)
      x = self.norml(x + rest_att_self)

      rest_att_cros = self.att_cros(x, encoder_output, encoder_output)
      x = self.norm2(x + rest_att_cros)

      res_att_cros = self.att_cros(x, x, x)
      x = self.norm3(x + res_att_cros)

      x = self.feed_forward(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1173791051.py in <cell line: 0>()
# ----> 1 class MeuBlocoDecoder(nn.Module):
#       2   def __init__(self, model_dim, vocab_size, n_heads, n_layers):
#       3     super().__init__()
#       4     self.norm1 = nn.LayerNorm(model_dim)
#       5     self.norm2 = nn.LayerNorm(model_dim)
#
# NameError: name 'nn' is not defined
